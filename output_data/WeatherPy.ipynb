# %% [markdown]
# # WeatherPy
#
#
# ### Collect cities weather data
#
#
# ### Plot the data
#
# * Temperature (F) vs. Latitude
#
# * Humidity (%) vs. Latitude
#
# * Cloudiness (%) vs. Latitude
#
# * Wind Speed (mph) vs. Latitude
#
#
# ### Linear regression
#
# * North/South Hemisphere : Temperature (F) vs. Latitude
#
# * North/South Hemisphere : Humidity (%) vs. Latitude
#
# * North/South Hemisphere : Cloudiness (%) vs. Latitude
#
# * North/South Hemisphere : Wind Speed (mph) vs. Latitude

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities_weathers.csv"

# %% [markdown]
# ## Collect cities weather data
# ----
#
# ### Generate Cities List

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %% [markdown]
# ### Perform API Calls
#
# * Perform a weather check on each city using a series of successive API calls.

# %%
weather_url = "http://api.openweathermap.org/data/2.5/weather?q="

# To store the weather informations
city_id = []
city_list = []
country = []
date = [] 
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []

for i in range(len(cities)):
    
    city_name = '+'.join(cities[i].split(' '))

    city_query_url = weather_url + city_name + "&appid=" + weather_api_key
    city_data = requests.get(city_query_url).json()

    try:
        print(f"It's being processed: {i}-th city = {city_data['name']}:")
        # Retrieve city info and weather informations
        city_id.append(city_data['id'])
        city_list.append(city_data['name'])
        country.append(city_data['sys']['country'])
        date.append(city_data['dt'])
        lat.append(city_data['coord']['lat'])
        lng.append(city_data['coord']['lon'])
        max_temp.append(city_data['main']['temp_max'])
        humidity.append(city_data['main']['humidity'])
        cloudiness.append(city_data['clouds']['all'])
        wind_speed.append(city_data['wind']['speed'])
    except KeyError:
        print(f"Found error : {i}-th city = {city_name} not found")
# Out:
# It's being processed: 0-th city = Albany:
# It's being processed: 1-th city = Provideniya:
# It's being processed: 2-th city = Qaanaaq:
# It's being processed: 3-th city = Jamestown:
# It's being processed: 4-th city = Asău:
# It's being processed: 5-th city = Yerbogachën:
# It's being processed: 6-th city = Broome:
# It's being processed: 7-th city = Meulaboh:
# It's being processed: 8-th city = Hobart:
# It's being processed: 9-th city = Ribeira Grande:
# It's being processed: 10-th city = Hermanus:
# It's being processed: 11-th city = Mayumba:
# Found error : 12-th city = thilogne not found
# It's being processed: 13-th city = Port Blair:
# It's being processed: 14-th city = Pisco:
# It's being processed: 15-th city = Kaitangata:
# It's being processed: 16-th city = Tiksi:
# It's being processed: 17-th city = Auki:
# It's being processed: 18-th city = Samarai:
# It's being processed: 19-th city = Punta Arenas:
# It's being processed: 20-th city = George Town:
# It's being processed: 21-th city = Vredendal:
# Found error : 22-th city = galiwinku not found
# It's being processed: 23-th city = Hithadhoo:
# It's being processed: 24-th city = Laas:
# It's being processed: 25-th city = Airai:
# It's being processed: 26-th city = Bengkulu:
# It's being processed: 27-th city = Bluff:
# It's being processed: 28-th city = Hilo:
# It's being processed: 29-th city = Faanui:
# It's being processed: 30-th city = Saint-Philippe:
# Found error : 31-th city = ngukurr not found
# It's being processed: 32-th city = Arraial do Cabo:
# It's being processed: 33-th city = Bouna:
# It's being processed: 34-th city = Louth:
# It's being processed: 35-th city = Labuhan:
# It's being processed: 36-th city = Rocha:
# Found error : 37-th city = amderma not found
# It's being processed: 38-th city = Saskylakh:
# Found error : 39-th city = illoqqortoormiut not found
# It's being processed: 40-th city = Toamasina:
# It's being processed: 41-th city = Nome:
# It's being processed: 42-th city = Lüderitz:
# It's being processed: 43-th city = Bambous Virieux:
# Found error : 44-th city = tumannyy not found
# It's being processed: 45-th city = Castro:
# It's being processed: 46-th city = Benghazi:
# Found error : 47-th city = bargal not found
# It's being processed: 48-th city = Rikitea:
# It's being processed: 49-th city = Tasiilaq:
# It's being processed: 50-th city = Lavrentiya:
# It's being processed: 51-th city = Nioro:
# It's being processed: 52-th city = Bonthe:
# It's being processed: 53-th city = Riverton:
# It's being processed: 54-th city = Zyryanovsk:
# It's being processed: 55-th city = Iracoubo:
# It's being processed: 56-th city = Busselton:
# It's being processed: 57-th city = Atuona:
# It's being processed: 58-th city = Vidim:
# It's being processed: 59-th city = Butaritari:
# It's being processed: 60-th city = Marsá Maţrūḩ:
# It's being processed: 61-th city = Cape Town:
# It's being processed: 62-th city = Nikolskoye:
# It's being processed: 63-th city = Zyryanka:
# It's being processed: 64-th city = Teya:
# It's being processed: 65-th city = Puerto Ayora:
# It's being processed: 66-th city = Norman Wells:
# It's being processed: 67-th city = Egvekinot:
# It's being processed: 68-th city = Saint Paul Harbor:
# It's being processed: 69-th city = Avera:
# It's being processed: 70-th city = Aksu:
# It's being processed: 71-th city = Panguma:
# It's being processed: 72-th city = Taltal:
# It's being processed: 73-th city = Buala:
# It's being processed: 74-th city = Port Elizabeth:
# It's being processed: 75-th city = Savé:
# It's being processed: 76-th city = Mataura:
# It's being processed: 77-th city = Amga:
# It's being processed: 78-th city = Cambridge:
# It's being processed: 79-th city = Avarua:
# Found error : 80-th city = taolanaro not found
# Found error : 81-th city = gorno-chuyskiy not found
# It's being processed: 82-th city = Laem Sing:
# It's being processed: 83-th city = Flinders:
# It's being processed: 84-th city = Biak:
# It's being processed: 85-th city = Letlhakane:
# It's being processed: 86-th city = Tegul'det:
# It's being processed: 87-th city = São Filipe:
# It's being processed: 88-th city = Port Alfred:
# It's being processed: 89-th city = Mount Gambier:
# It's being processed: 90-th city = Haines Junction:
# It's being processed: 91-th city = Gijang:
# It's being processed: 92-th city = Padang:
# It's being processed: 93-th city = Tavda:
# It's being processed: 94-th city = Tamworth:
# It's being processed: 95-th city = Bathsheba:
# It's being processed: 96-th city = Lamar:
# It's being processed: 97-th city = Priiskovyy:
# Found error : 98-th city = sorvag not found
# Found error : 99-th city = belushya+guba not found
# Found error : 100-th city = tsihombe not found
# It's being processed: 101-th city = Ushuaia:
# It's being processed: 102-th city = Khatanga:
# It's being processed: 103-th city = Flin Flon:
# It's being processed: 104-th city = Longyearbyen:
# It's being processed: 105-th city = Thompson:
# It's being processed: 106-th city = Millinocket:
# It's being processed: 107-th city = Kol'chugino:
# It's being processed: 108-th city = Yellowknife:
# It's being processed: 109-th city = Río Gallegos:
# Found error : 110-th city = kuche not found
# It's being processed: 111-th city = Sinegor'ye:
# It's being processed: 112-th city = Suez:
# It's being processed: 113-th city = Les Escoumins:
# It's being processed: 114-th city = Caravelas:
# It's being processed: 115-th city = Davis:
# Found error : 116-th city = gangotri not found
# It's being processed: 117-th city = Bredasdorp:
# It's being processed: 118-th city = College:
# It's being processed: 119-th city = Tuatapere:
# It's being processed: 120-th city = Barrow:
# It's being processed: 121-th city = Srīvardhan:
# It's being processed: 122-th city = Cayenne:
# It's being processed: 123-th city = Beaupré:
# It's being processed: 124-th city = Vitorino Freire:
# Found error : 125-th city = samusu not found
# It's being processed: 126-th city = Pauini:
# It's being processed: 127-th city = Champerico:
# It's being processed: 128-th city = Kalevala:
# It's being processed: 129-th city = Yantai:
# It's being processed: 130-th city = Narsaq:
# It's being processed: 131-th city = Lagoa:
# It's being processed: 132-th city = Lebu:
# Found error : 133-th city = sentyabrskiy not found
# It's being processed: 134-th city = Half Moon Bay:
# Found error : 135-th city = toulepleu not found
# It's being processed: 136-th city = Maryville:
# It's being processed: 137-th city = Thinadhoo:
# It's being processed: 138-th city = Lexington:
# It's being processed: 139-th city = Homer:
# It's being processed: 140-th city = Nichinan:
# It's being processed: 141-th city = Kapaa:
# It's being processed: 142-th city = Chui:
# It's being processed: 143-th city = Port Hardy:
# It's being processed: 144-th city = Luena:
# It's being processed: 145-th city = Clemmons:
# It's being processed: 146-th city = Lisala:
# It's being processed: 147-th city = Upernavik:
# It's being processed: 148-th city = Ubinskoye:
# It's being processed: 149-th city = Tiznit Province:
# It's being processed: 150-th city = Lhokseumawe:
# It's being processed: 151-th city = Vaini:
# It's being processed: 152-th city = Nanortalik:
# It's being processed: 153-th city = Gamba:
# It's being processed: 154-th city = Kaeo:
# It's being processed: 155-th city = Raudeberg:
# It's being processed: 156-th city = Hasaki:
# It's being processed: 157-th city = Härnösand:
# It's being processed: 158-th city = Nemuro:
# It's being processed: 159-th city = Mahébourg:
# It's being processed: 160-th city = Sungurlu:
# It's being processed: 161-th city = Bilma:
# It's being processed: 162-th city = Namatanai:
# Found error : 163-th city = sapao not found
# It's being processed: 164-th city = Torbay:
# It's being processed: 165-th city = Abu Dhabi:
# It's being processed: 166-th city = Ponta Delgada:
# It's being processed: 167-th city = Cruz Grande:
# It's being processed: 168-th city = Outlook:
# It's being processed: 169-th city = Kiama:
# It's being processed: 170-th city = Palmer:
# It's being processed: 171-th city = Tubualá:
# It's being processed: 172-th city = Ahipara:
# It's being processed: 173-th city = Huanren:
# It's being processed: 174-th city = Cidreira:
# It's being processed: 175-th city = Tuktoyaktuk:
# Found error : 176-th city = louisbourg not found
# It's being processed: 177-th city = Khvoynaya:
# Found error : 178-th city = phrai+bung not found
# It's being processed: 179-th city = Ormara:
# It's being processed: 180-th city = Ji’an:
# Found error : 181-th city = mys+shmidta not found
# It's being processed: 182-th city = Takanosu:
# It's being processed: 183-th city = Riyadh:
# It's being processed: 184-th city = Luganville:
# It's being processed: 185-th city = Santa Vitória do Palmar:
# It's being processed: 186-th city = Tiarei:
# It's being processed: 187-th city = Charters Towers:
# It's being processed: 188-th city = Banda Aceh:
# It's being processed: 189-th city = San Juan:
# It's being processed: 190-th city = Saint-Augustin:
# It's being processed: 191-th city = Ponta do Sol:
# It's being processed: 192-th city = Hamilton:
# It's being processed: 193-th city = Belaya Gora:
# It's being processed: 194-th city = Redlands:
# It's being processed: 195-th city = Parrita:
# It's being processed: 196-th city = Constitución:
# It's being processed: 197-th city = Honiara:
# It's being processed: 198-th city = Sargūr:
# It's being processed: 199-th city = Saint George:
# It's being processed: 200-th city = Praia da Vitória:
# It's being processed: 201-th city = Severo-Kuril'sk:
# It's being processed: 202-th city = Ancud:
# It's being processed: 203-th city = Grimma:
# It's being processed: 204-th city = Bahía Blanca:
# Found error : 205-th city = andevoranto not found
# It's being processed: 206-th city = Kamloops:
# It's being processed: 207-th city = Southbridge:
# It's being processed: 208-th city = New Norfolk:
# It's being processed: 209-th city = Pevek:
# It's being processed: 210-th city = Kavieng:
# It's being processed: 211-th city = Alofi:
# It's being processed: 212-th city = Anadyr:
# It's being processed: 213-th city = Zhoucheng:
# It's being processed: 214-th city = Adrar:
# Found error : 215-th city = kerteh not found
# It's being processed: 216-th city = Diffa:
# It's being processed: 217-th city = Tărtăşeşti:
# It's being processed: 218-th city = Katsuura:
# It's being processed: 219-th city = Bismarck:
# Found error : 220-th city = cam+pha not found
# It's being processed: 221-th city = Caceres:
# It's being processed: 222-th city = Esperance:
# It's being processed: 223-th city = Kahului:
# It's being processed: 224-th city = Kishtwār:
# It's being processed: 225-th city = Saint Anthony:
# It's being processed: 226-th city = Zhangzhou:
# It's being processed: 227-th city = Hofn:
# It's being processed: 228-th city = Cherskiy:
# It's being processed: 229-th city = Atar:
# It's being processed: 230-th city = Bodden Town:
# It's being processed: 231-th city = San Jerónimo:
# It's being processed: 232-th city = Adwa:
# It's being processed: 233-th city = Ţahţā:
# It's being processed: 234-th city = Safi:
# It's being processed: 235-th city = Kudahuvadhoo:
# It's being processed: 236-th city = Muhafazat Lahij:
# It's being processed: 237-th city = Hobyo:
# It's being processed: 238-th city = Winnemucca:
# It's being processed: 239-th city = Wajima:
# It's being processed: 240-th city = Nishihara:
# It's being processed: 241-th city = Bisira:
# It's being processed: 242-th city = Beringovskiy:
# It's being processed: 243-th city = Aksarka:
# It's being processed: 244-th city = Coyhaique:
# It's being processed: 245-th city = Linjiang:
# It's being processed: 246-th city = Lompoc:
# It's being processed: 247-th city = Constantine:
# It's being processed: 248-th city = Várzea da Palma:
# It's being processed: 249-th city = San Policarpo:
# It's being processed: 250-th city = Sandūr:
# Found error : 251-th city = grand+river+south+east not found
# It's being processed: 252-th city = Chokurdakh:
# It's being processed: 253-th city = Port Lincoln:
# It's being processed: 254-th city = Walvis Bay:
# It's being processed: 255-th city = Cukai:
# It's being processed: 256-th city = Bubaque:
# It's being processed: 257-th city = Bethel:
# It's being processed: 258-th city = Krasnorechenskiy:
# It's being processed: 259-th city = Almaznyy:
# Found error : 260-th city = nguiu not found
# It's being processed: 261-th city = Biała Podlaska:
# It's being processed: 262-th city = Moindou:
# It's being processed: 263-th city = Shiraz:
# It's being processed: 264-th city = Kavaratti:
# It's being processed: 265-th city = São Félix do Xingu:
# It's being processed: 266-th city = Carnarvon:
# It's being processed: 267-th city = Monrovia:
# It's being processed: 268-th city = Ōdachō-ōda:
# It's being processed: 269-th city = Dumas:
# It's being processed: 270-th city = Sørland:
# It's being processed: 271-th city = Isla Vista:
# It's being processed: 272-th city = Virbalis:
# It's being processed: 273-th city = Moose Factory:
# It's being processed: 274-th city = Dickinson:
# It's being processed: 275-th city = Ostrovnoy:
# It's being processed: 276-th city = Aykhal:
# It's being processed: 277-th city = Barcelos:
# It's being processed: 278-th city = Baishishan:
# It's being processed: 279-th city = Snezhnogorsk:
# It's being processed: 280-th city = Brae:
# It's being processed: 281-th city = Richards Bay:
# It's being processed: 282-th city = Clyde River:
# It's being processed: 283-th city = Chengzhong:
# It's being processed: 284-th city = Lukovetskiy:
# Found error : 285-th city = vaitupu not found
# It's being processed: 286-th city = Kolpny:
# It's being processed: 287-th city = Drăguşeni:
# It's being processed: 288-th city = Tinskoy:
# It's being processed: 289-th city = Dingle:
# It's being processed: 290-th city = Watertown:
# Found error : 291-th city = barentsburg not found
# It's being processed: 292-th city = Gerāsh:
# It's being processed: 293-th city = Laguna:
# It's being processed: 294-th city = Umluj:
# It's being processed: 295-th city = Ballina:
# It's being processed: 296-th city = Virginia Beach:
# It's being processed: 297-th city = Codrington:
# It's being processed: 298-th city = Sanguéya:
# It's being processed: 299-th city = Vila Franca do Campo:
# It's being processed: 300-th city = Basarabeasca:
# It's being processed: 301-th city = Port-Gentil:
# It's being processed: 302-th city = Berlevåg:
# It's being processed: 303-th city = Ust'-Kulom:
# It's being processed: 304-th city = Dunedin:
# It's being processed: 305-th city = Shihezi:
# It's being processed: 306-th city = Fort Nelson:
# Found error : 307-th city = litoral+del+san+juan not found
# Found error : 308-th city = kerki not found
# It's being processed: 309-th city = Devils Lake:
# It's being processed: 310-th city = Grand Gaube:
# It's being processed: 311-th city = Tottori-shi:
# It's being processed: 312-th city = Chicomuselo:
# It's being processed: 313-th city = Paamiut:
# It's being processed: 314-th city = Kloulklubed:
# It's being processed: 315-th city = Saldanha:
# It's being processed: 316-th city = Fortuna:
# Found error : 317-th city = tambul not found
# It's being processed: 318-th city = Khāsh:
# It's being processed: 319-th city = Ol'khovatka:
# It's being processed: 320-th city = Iqaluit:
# It's being processed: 321-th city = Dakar:
# It's being processed: 322-th city = Hirara:
# It's being processed: 323-th city = Kenai:
# It's being processed: 324-th city = San Cristobal:
# Found error : 325-th city = tasbuget not found
# It's being processed: 326-th city = Antalaha:
# Found error : 327-th city = lephepe not found
# It's being processed: 328-th city = Mathbaria:
# It's being processed: 329-th city = Ixtapa:
# It's being processed: 330-th city = Banjar:
# It's being processed: 331-th city = Lyman:
# It's being processed: 332-th city = Marsh Harbour:
# It's being processed: 333-th city = Lasem:
# It's being processed: 334-th city = Zaysan:
# It's being processed: 335-th city = Hohhot:
# It's being processed: 336-th city = Morón:
# It's being processed: 337-th city = Kaz:
# It's being processed: 338-th city = Tanout:
# It's being processed: 339-th city = Uvel'skiy:
# Found error : 340-th city = el+balyana not found
# It's being processed: 341-th city = Nyurba:
# It's being processed: 342-th city = Wakkanai:
# It's being processed: 343-th city = Sakakah:
# It's being processed: 344-th city = Coahuayana Viejo:
# It's being processed: 345-th city = Mendi:
# It's being processed: 346-th city = Puerto Escondido:
# It's being processed: 347-th city = Maromitsa:
# It's being processed: 348-th city = Iskateley:
# It's being processed: 349-th city = Husavik:
# It's being processed: 350-th city = Isoka:
# It's being processed: 351-th city = Bela Vista:
# Found error : 352-th city = mrirt not found
# It's being processed: 353-th city = Westport:
# It's being processed: 354-th city = Onega:
# It's being processed: 355-th city = Sechelt:
# It's being processed: 356-th city = San Quintín:
# It's being processed: 357-th city = North Bend:
# It's being processed: 358-th city = Dikson:
# It's being processed: 359-th city = Kharp:
# It's being processed: 360-th city = Pangody:
# It's being processed: 361-th city = Boden:
# It's being processed: 362-th city = East London:
# It's being processed: 363-th city = Makakilo City:
# It's being processed: 364-th city = Sabha:
# It's being processed: 365-th city = Yenotayevka:
# It's being processed: 366-th city = Buchanan:
# Found error : 367-th city = kawana+waters not found
# Found error : 368-th city = saleaula not found
# It's being processed: 369-th city = Hong Kong:
# It's being processed: 370-th city = Sungai Raya:
# It's being processed: 371-th city = Okakarara:
# It's being processed: 372-th city = Arai:
# It's being processed: 373-th city = Angoche:
# It's being processed: 374-th city = Vila Velha:
# It's being processed: 375-th city = Savannah Bight:
# It's being processed: 376-th city = Ushtobe:
# It's being processed: 377-th city = Harper:
# It's being processed: 378-th city = Geraldton:
# It's being processed: 379-th city = Puerto Madryn:
# It's being processed: 380-th city = Sur:
# It's being processed: 381-th city = Manitouwadge:
# It's being processed: 382-th city = Puerto Maldonado:
# It's being processed: 383-th city = Boddam:
# It's being processed: 384-th city = Yar-Sale:
# It's being processed: 385-th city = Fuyu:
# It's being processed: 386-th city = Evensk:
# It's being processed: 387-th city = Talnakh:
# It's being processed: 388-th city = Mossamedes:
# It's being processed: 389-th city = Grand-Santi:
# It's being processed: 390-th city = Sena Madureira:
# It's being processed: 391-th city = Illela:
# Found error : 392-th city = halalo not found
# It's being processed: 393-th city = Mar del Plata:
# It's being processed: 394-th city = Umi:
# It's being processed: 395-th city = Sitka:
# It's being processed: 396-th city = Martapura:
# It's being processed: 397-th city = Bereda:
# It's being processed: 398-th city = Sisimiut:
# Found error : 399-th city = rungata not found
# It's being processed: 400-th city = São Benedito do Rio Preto:
# It's being processed: 401-th city = Araouane:
# It's being processed: 402-th city = Porto Santo:
# It's being processed: 403-th city = San Patricio:
# It's being processed: 404-th city = Dalbandin:
# It's being processed: 405-th city = Carbonia:
# It's being processed: 406-th city = Kirove:
# It's being processed: 407-th city = Khovd:
# It's being processed: 408-th city = Manta:
# It's being processed: 409-th city = Anloga:
# Found error : 410-th city = talawdi not found
# It's being processed: 411-th city = Prado:
# It's being processed: 412-th city = Plettenberg Bay:
# Found error : 413-th city = sinkat not found
# It's being processed: 414-th city = Lodwar:
# It's being processed: 415-th city = Zhangjiakou Shi Xuanhua Qu:
# It's being processed: 416-th city = Wuda:
# Found error : 417-th city = karaul not found
# It's being processed: 418-th city = Kungurtug:
# It's being processed: 419-th city = Grindavik:
# It's being processed: 420-th city = Los Llanos de Aridane:
# Found error : 421-th city = palabuhanratu not found
# It's being processed: 422-th city = Sohag:
# It's being processed: 423-th city = Sonqor:
# Found error : 424-th city = burica not found
# It's being processed: 425-th city = Pilar do Sul:
# It's being processed: 426-th city = Imbituba:
# It's being processed: 427-th city = Hammerfest:
# It's being processed: 428-th city = Goderich:
# It's being processed: 429-th city = Conde:
# It's being processed: 430-th city = Togur:
# It's being processed: 431-th city = Hambantota:
# It's being processed: 432-th city = Muros:
# It's being processed: 433-th city = Kruisfontein:
# It's being processed: 434-th city = Chicama:
# It's being processed: 435-th city = Makat:
# It's being processed: 436-th city = Baykit:
# It's being processed: 437-th city = San Lorenzo:
# It's being processed: 438-th city = Aquin:
# It's being processed: 439-th city = Porto-Novo:
# It's being processed: 440-th city = Parfen'yevo:
# It's being processed: 441-th city = Ekhabi:
# Found error : 442-th city = burkhala not found
# Found error : 443-th city = marcona not found
# It's being processed: 444-th city = Isangel:
# Found error : 445-th city = bolshaya+chernigovka not found
# It's being processed: 446-th city = Vanimo:
# It's being processed: 447-th city = Te Anau:
# It's being processed: 448-th city = Milledgeville:
# It's being processed: 449-th city = St. George's:
# Found error : 450-th city = yanan not found
# It's being processed: 451-th city = Abdulino:
# It's being processed: 452-th city = Cabo San Lucas:
# It's being processed: 453-th city = Taoudenni:
# It's being processed: 454-th city = Atasū:
# It's being processed: 455-th city = Jonesboro:
# It's being processed: 456-th city = Ratnagiri:
# It's being processed: 457-th city = Fürstenfeld:
# It's being processed: 458-th city = Morant Bay:
# It's being processed: 459-th city = Khasan:
# It's being processed: 460-th city = Kumul:
# It's being processed: 461-th city = Comodoro Rivadavia:
# It's being processed: 462-th city = Lengshuijiang:
# It's being processed: 463-th city = Srednyaya Yelyuzan’:
# It's being processed: 464-th city = Cherdyn':
# It's being processed: 465-th city = Andros Town:
# It's being processed: 466-th city = Broken Hill:
# It's being processed: 467-th city = Koumac:
# It's being processed: 468-th city = Cockburn Town:
# It's being processed: 469-th city = Ubatuba:
# It's being processed: 470-th city = San Miguel de Cozumel:
# It's being processed: 471-th city = Oistins:
# It's being processed: 472-th city = Aripuanã:
# Found error : 473-th city = mahaicony not found
# It's being processed: 474-th city = Souillac:
# It's being processed: 475-th city = Celestún:
# It's being processed: 476-th city = Tevriz:
# It's being processed: 477-th city = Tilichiki:
# Found error : 478-th city = araguatins not found
# It's being processed: 479-th city = Tomatlán:
# It's being processed: 480-th city = Voinka:
# It's being processed: 481-th city = Lishan:
# It's being processed: 482-th city = Amapá:
# It's being processed: 483-th city = Ilo:
# It's being processed: 484-th city = Joshīmath:
# It's being processed: 485-th city = Taos:
# It's being processed: 486-th city = Sambava:
# Found error : 487-th city = mocambique not found
# It's being processed: 488-th city = Preobrazheniye:
# It's being processed: 489-th city = Tsabong:
# It's being processed: 490-th city = Goianésia:
# It's being processed: 491-th city = Shenjiamen:
# It's being processed: 492-th city = Vyartsilya:
# It's being processed: 493-th city = George:
# It's being processed: 494-th city = Guarujá:
# Found error : 495-th city = katsiveli not found
# It's being processed: 496-th city = Wawa:
# It's being processed: 497-th city = Tooele:
# It's being processed: 498-th city = Takoradze:
# It's being processed: 499-th city = Örnsköldsvik:
# It's being processed: 500-th city = Springville:
# It's being processed: 501-th city = Wattegama:
# It's being processed: 502-th city = Yaan:
# It's being processed: 503-th city = Micomeseng:
# It's being processed: 504-th city = Bonavista:
# It's being processed: 505-th city = Doha:
# It's being processed: 506-th city = Cururupu:
# It's being processed: 507-th city = Bom Jesus:
# It's being processed: 508-th city = Wilmington:
# It's being processed: 509-th city = Meybod:
# It's being processed: 510-th city = Bumba:
# It's being processed: 511-th city = Rawson:
# It's being processed: 512-th city = Venado:
# It's being processed: 513-th city = Philadelphia:
# It's being processed: 514-th city = Tual:
# It's being processed: 515-th city = Alice Springs:
# It's being processed: 516-th city = Lata:
# It's being processed: 517-th city = Nouadhibou:
# It's being processed: 518-th city = Otavi:
# It's being processed: 519-th city = Fereydūnkenār:
# It's being processed: 520-th city = Kirksville:
# It's being processed: 521-th city = Bacolod City:
# It's being processed: 522-th city = Merrill:
# It's being processed: 523-th city = Sugod:
# It's being processed: 524-th city = Kerman:
# It's being processed: 525-th city = Pacific Grove:
# It's being processed: 526-th city = Santa Maria:
# Found error : 527-th city = lolua not found
# It's being processed: 528-th city = Chunhuhub:
# It's being processed: 529-th city = Tha Chang:
# It's being processed: 530-th city = Kupang:
# Found error : 531-th city = nizhneyansk not found
# It's being processed: 532-th city = Flagstaff:
# It's being processed: 533-th city = Boissevain:
# It's being processed: 534-th city = Coruripe:
# It's being processed: 535-th city = Tandil:
# It's being processed: 536-th city = Tutóia:
# It's being processed: 537-th city = Port Hedland:
# It's being processed: 538-th city = Vallenar:
# It's being processed: 539-th city = Tamboril:
# It's being processed: 540-th city = Tabou:
# It's being processed: 541-th city = Omboué:
# It's being processed: 542-th city = Coquimbo:
# It's being processed: 543-th city = Sidi Ali:
# It's being processed: 544-th city = Kozhva:
# It's being processed: 545-th city = Lima:
# It's being processed: 546-th city = Kununurra:
# It's being processed: 547-th city = Toowoomba:
# It's being processed: 548-th city = Klaksvík:
# It's being processed: 549-th city = Qasigiannguit:
# It's being processed: 550-th city = Fairbanks:
# It's being processed: 551-th city = Whitehorse:
# It's being processed: 552-th city = Buin:
# It's being processed: 553-th city = Tarakan:
# It's being processed: 554-th city = Susuman:
# It's being processed: 555-th city = Rodolfo Sánchez Taboada:
# It's being processed: 556-th city = Dukat:
# It's being processed: 557-th city = Peno:
# It's being processed: 558-th city = Aswān:
# It's being processed: 559-th city = Udachny:
# It's being processed: 560-th city = Nuuk:
# It's being processed: 561-th city = Bud:
# It's being processed: 562-th city = Jiuquan:
# It's being processed: 563-th city = Progreso:
# It's being processed: 564-th city = Yumen:
# It's being processed: 565-th city = Benguela:
# It's being processed: 566-th city = Ḩasanābād:
# It's being processed: 567-th city = Mitsamiouli:
# It's being processed: 568-th city = Okha:
# Found error : 569-th city = karamea not found
# It's being processed: 570-th city = Omsukchan:
# It's being processed: 571-th city = Saint-Leu:
# It's being processed: 572-th city = Shingū:
# It's being processed: 573-th city = Mulegé:
# It's being processed: 574-th city = Bandiagara:
# It's being processed: 575-th city = Nuquí:
# It's being processed: 576-th city = Mt. Pleasant:
# It's being processed: 577-th city = Vicuña:
# It's being processed: 578-th city = Lac du Bonnet:
# It's being processed: 579-th city = Chernyshevskiy:
# It's being processed: 580-th city = Ilulissat:
# It's being processed: 581-th city = Sri Aman:
# It's being processed: 582-th city = Ojinaga:
# Found error : 583-th city = ijaki not found
# It's being processed: 584-th city = Ionia:
# It's being processed: 585-th city = Srednekolymsk:
# It's being processed: 586-th city = Lorengau:
# It's being processed: 587-th city = Kurchum:
# It's being processed: 588-th city = The Valley:
# It's being processed: 589-th city = Takaka:
# It's being processed: 590-th city = Viseu:
# It's being processed: 591-th city = Dallas:
# It's being processed: 592-th city = Zaria:
# It's being processed: 593-th city = Distrikt Brokopondo:
# It's being processed: 594-th city = Camopi:
# It's being processed: 595-th city = Arrondissement de Lannion:
# It's being processed: 596-th city = Bilibino:
# Found error : 597-th city = karamay not found
# It's being processed: 598-th city = Biltine:

# %% [markdown]
# ### Convert Raw Data to DataFrame
#
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({
    'City ID' : city_id,
    'City' : city_list,
    'Country' : country,
    'Date' : date,
    'Lat' : lat,
    'Lng' : lng,
    'Max Temp (F)' : [(k - 273.15) * (9/5) + 32 for k in max_temp],
    'Humidity' : humidity,
    'Cloudiness' : cloudiness,
    'Wind Speed' : wind_speed})

# Export file as a CSV, without the Pandas index, but with the header
weather_df.to_csv(output_data_file, index=False, header=True)

# %%
weather_df.head()
# Out:
#    City ID         City Country        Date    Lat     Lng  Max Temp (F)  \
# 0  5106841       Albany      US  1594699812  42.60  -73.97        73.004
# 1  4031574  Provideniya      RU  1594700035  64.38 -173.30        50.000
# 2  3831208      Qaanaaq      GL  1594699991  77.48  -69.36        41.522
# 3  5122534    Jamestown      US  1594699977  42.10  -79.24        62.600
# 4   686090         Asău      RO  1594700083  46.43   26.40        57.200
#
#    Humidity  Cloudiness  Wind Speed
# 0        71          32        3.34
# 1        81          90        6.00
# 2        72           1        1.24
# 3        82           1        2.10
# 4        71          19        1.00

# %%
city_weather_df.count()
# Out:
# City ID         542
# City            542
# Country         542
# Date            542
# Lat             542
# Lng             542
# Max Temp (F)    542
# Humidity        542
# Cloudiness      542
# Wind Speed      542
# dtype: int64

# %% [markdown]
# ### Inspect the data and remove the cities where the humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humid_cities = weather_df.loc[weather_df['Humidity']>100]
if len(humid_cities.index) == 0:
    print("There are no cities that have humidity more than 100%")
else:
    weather_df.drop(humid_cities.index, inplace=True)
    weather_df.to_csv(output_data_file, index=False, header=True)
# Out:
# There are no cities that have humidity more than 100%

# %%
# Get the observed date
date = pd.to_datetime(weather_df['Date'],unit='s')[0].date()

# %% [markdown]
# ## Plot the Data
# ----

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
xval = weather_df['Lat']
yval = weather_df['Max Temp (F)']
plt.scatter(xval, yval, facecolor='mediumblue', alpha= 0.7, edgecolors='darkblue')
plt.grid(alpha=0.5)
plt.title(f"Latitude vs. Max Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.tight_layout()
plt.savefig("output_data/lat_temperature")
plt.show()

# %% [markdown]
# Overall, the points form a concave down parabola with the vertex at the latitude 20. This tells that the equater is not the hottest location. The higher termperatures are shown in the slightly northern area from the equater.

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
xval = weather_df['Lat']
yval = weather_df['Humidity']
plt.scatter(xval, yval, facecolor='mediumblue', alpha= 0.7, edgecolors='darkblue')
plt.grid(alpha=0.5)
plt.title(f"Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()
plt.savefig("output_data/lat_humidity")
plt.show()

# %% [markdown]
# The above plot shows the relationship between the humidity and the latitude. The points at the equater appear in the high humidity range. Overall, it seems there is no relation between the humidity and the latitude.

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
xval = weather_df['Lat']
yval = weather_df['Cloudiness']
plt.scatter(xval, yval, facecolor='mediumblue', alpha= 0.7, edgecolors='darkblue')
plt.grid(alpha=0.5)
plt.title(f"Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.tight_layout()
plt.savefig("output_data/lat_cloudiness")
plt.show()

# %% [markdown]
# The plot above shows the relationship between the cloudiness and the latitude. The points are spread out. It is hard to see any relation between the cloudiness and the latitude.

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
xval = weather_df['Lat']
yval = weather_df['Wind Speed']
plt.scatter(xval, yval, facecolor='mediumblue', alpha= 0.7, edgecolors='darkblue')
plt.grid(alpha=0.5)
plt.title(f"Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.tight_layout()
plt.savefig("output_data/lat_windspeed")
plt.show()

# %% [markdown]
# The points on the plot show the wind speed of the cities is generally linear relationship to the latitude with almost zero slope. It seems the wind speed overall similar throught the latitudes.

# %% [markdown]
# ## Linear Regression
# ----

# %%
# Create a function to create Linear Regression plots
def subplot_linregression(ax, xval, yval):
    
    (mm,cc,rr,pp,ss) = linregress(xval,yval)
    line_eq = "y = " + str(round(mm,2)) + " x + " + str(round(cc,2))
    est_yval = mm*xval + cc
    
    ax.plot(xval, est_yval, "r-")
    ax.annotate(line_eq, (5, 205), color="red", xycoords='axes points', size=12)
    ax.scatter(xval, yval, facecolor='mediumblue', alpha= 0.7, edgecolors='darkblue')    
    ax.set_xlabel("Latitude")
    
    return rr

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = weather_df.loc[weather_df['Lat']>0]
south_df = weather_df.loc[weather_df['Lat']<0]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression
#
# * North Hemisphere
# * South Hemisphere

# %%
# Set the figure for the linear regression plots
fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(10,4))
fig.suptitle(f"Max Temerature (F) vs. Latitude ({date})", size=14)

# Subplot for the north hemisphere
ax1.set_title("North Hemisphere")
n_rr = subplot_linregression(ax1, north_df['Lat'], north_df['Max Temp (F)'])

# Subplot for the north hemisphere
ax2.set_title("South Hemisphere")
s_rr = subplot_linregression(ax2, south_df['Lat'], south_df['Max Temp (F)'])
                
plt.show()

# Print the r-squared value
print(f"The r-sq of North Hemisphere are {n_rr**2}")
print(f"The r-sq of South Hemisphere are {s_rr**2}")
# Out:
# The r-sq of North Hemisphere are 0.42433976518773414
# The r-sq of South Hemisphere are 0.6334928919815652

# %% [markdown]
# The equations of the linear regressions are given on the top left corner. The models tell
#
# * North Hemisphere: The temperature decreases 0.42 F for one latitude increase and the temperature near the equator is 87.20 F. The $r^2=0.42$ means that the linear regression explains 42% of the observed variance in the temperature.
#
# * South Hemisphere: The temperature decreases 0.86 F for one latitude decrease and the temperature near the equator is 81.03 F. The $r^2=0.63$ means that the linear regression explains 63% of the observed variance in the temperature.

# %% [markdown]
# ###  Humidity (%) vs. Latitude Linear Regression
#
# * North Hemisphere
# * South Hemisphere

# %%
# Set the figure for the linear regression plots
fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(10,4))
fig.suptitle(f"Humidity (%) vs. Latitude ({date})", size=14)

# Subplot for the north hemisphere
ax1.set_title("North Hemisphere")
n_rr = subplot_linregression(ax1, north_df['Lat'], north_df['Humidity'])

# Subplot for the north hemisphere
ax2.set_title("South Hemisphere")
s_rr = subplot_linregression(ax2, south_df['Lat'], south_df['Humidity'])
                
plt.show()

# Print the r-squared value
print(f"The r-sq of North Hemisphere are {n_rr**2}")
print(f"The r-sq of South Hemisphere are {s_rr**2}")
# Out:
# The r-sq of North Hemisphere are 0.006922315874854903
# The r-sq of South Hemisphere are 0.0018617707308094345

# %% [markdown]
# The equations of the linear regressions are given on the top left corner. The models tell
#
# * North Hemisphere: The humidity increases 0.09% for one latitude increase and the humidity near the equator is 73.77%. The $r^2=0.007$ means that the linear regression explains only 0.7% of the observed variance in the humidity data.
#
# * South Hemisphere: The humidity decreases 0.06% for one latitude decrease and the humidity near the equator is 74.67%. The $r^2=0.002$ means that the linear regression explains only 0.2% of the observed variance in the humidity data.

# %% [markdown]
# ###  Cloudiness (%) vs. Latitude Linear Regression
#
# * North Hemisphere
# * South Hemisphere

# %%
# Set the figure for the linear regression plots
fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(10,4))
fig.suptitle(f"Cloudiness (%) vs. Latitude ({date})", size=14)

# Subplot for the north hemisphere
ax1.set_title("North Hemisphere")
n_rr = subplot_linregression(ax1, north_df['Lat'], north_df['Cloudiness'])

# Subplot for the north hemisphere
ax2.set_title("South Hemisphere")
s_rr = subplot_linregression(ax2, south_df['Lat'], south_df['Cloudiness'])
                
plt.show()

# Print the r-squared value
print(f"The r-sq of North Hemisphere are {n_rr**2}")
print(f"The r-sq of South Hemisphere are {s_rr**2}")
# Out:
# The r-sq of North Hemisphere are 0.0028650333524780883
# The r-sq of South Hemisphere are 0.005592094212939261

# %% [markdown]
# The equations of the linear regressions are given on the top left corner. The models tell
#
# * North Hemisphere: The cloudiness increases 0.1% for one latitude increase and the cloudiness near the equator is 45.18%. The $r^2=0.0028$ means that the linear regression explains only 0.28% of the observed variance in the cloudiness data.
#
# * South Hemisphere: The cloudiness decreases 0.2% for one latitude decrease and the cloudiness near the equator is 48.26%. The $r^2=0.0055$ means that the linear regression explains only 0.55% of the observed variance in the cloudiness data.

# %% [markdown]
# ###  Wind Speed (mph) vs. Latitude Linear Regression
#
# * North Hemisphere
# * South Hemisphere

# %%
# Set the figure for the linear regression plots
fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(10,4))
fig.suptitle(f"Wind Speed (mph) vs. Latitude ({date})", size=14)

# Subplot for the north hemisphere
ax1.set_title("North Hemisphere")
n_rr = subplot_linregression(ax1, north_df['Lat'], north_df['Wind Speed'])

# Subplot for the north hemisphere
ax2.set_title("South Hemisphere")
s_rr = subplot_linregression(ax2, south_df['Lat'], south_df['Wind Speed'])
                
plt.show()

# Print the r-squared value
print(f"The r-sq of North Hemisphere are {n_rr**2}")
print(f"The r-sq of South Hemisphere are {s_rr**2}")
# Out:
# The r-sq of North Hemisphere are 6.368751715643792e-08
# The r-sq of South Hemisphere are 0.05129980635114851

# %% [markdown]
# The equations of the linear regressions are given on the top left corner. The models tell
#
# * North Hemisphere: The wind speed stays same for one latitude increase and the wind speed near the equator is 3.47mph. The $r^2=6.37\cdot 10^{-8}$ means that the linear regression explains almost 0% of the observed variance in the wind speed data.
#
# * South Hemisphere: The wind speed increases 0.05mph for one latitude decrease and the wind speed near the equator is 2.55mph. The $r^2=0.05$ means that the linear regression explains only 5% of the observed variance in the wind speed data.
